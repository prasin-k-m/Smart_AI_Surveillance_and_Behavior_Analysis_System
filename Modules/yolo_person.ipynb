# %%
from ultralytics import YOLO
import cv2
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, Image

# %%
model = YOLO('yolov8s.pt')

# %%
# result = model(r'testing_samples\single_person.jpg')

# result[0].show()

result = model(r'testing_samples\single_person.jpg')
result[0].show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 5
#       1 # result = model(r'testing_samples\single_person.jpg')
#       2
#       3 # result[0].show()
# ----> 5 result = model(r'testing_samples\single_person.jpg')
#       6 result[0].show()
#
# File c:\Users\user\Desktop\ML_PROJECT\Smart_AI_Surveillance_and_Behavior_Analysis_System\env\lib\site-packages\ultralytics\engine\model.py:177, in Model.__call__(self, source, stream, **kwargs)
#     149 def __call__(
#     150     self,
#     151     source: str | Path | int | Image.Image | list | tuple | np.ndarray | torch.Tensor = None,
#     152     stream: bool = False,
#     153     **kwargs: Any,
#     154 ) -> list:
#     155     """Alias for the predict method, enabling the model instance to be callable for predictions.
#     156
# ...

# %%
# group_result = model ("group.jpg")

# group_result[0].show()

# %%
import cv2

input_path = "person_tracking.avi"
output_path = "person_tracking_720p.avi"

cap = cv2.VideoCapture(input_path)

fourcc = cv2.VideoWriter_fourcc(*"XVID")
fps = cap.get(cv2.CAP_PROP_FPS)

out = cv2.VideoWriter(output_path, fourcc, fps, (1280, 720))

while True:
    ret, frame = cap.read()
    if not ret:
        break

    frame_resized = cv2.resize(frame, (1280, 720))
    out.write(frame_resized)

cap.release()
out.release()

print("Done! Saved as person_tracking_720p.avi")
# Out:
# Done! Saved as person_tracking_720p.avi

# %%
video_result = model("person_tracking_720p.avi", save=True, conf=0.25)
# Out:
# WARNING
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/1003) c:\Users\user\Desktop\ML_PROJECT\Smart_AI_Surveillance_and_Behavior_Analysis_System\person_tracking_720p.avi: 384x640 14 persons, 1 car, 2 backpacks, 1 handbag, 2 cell phones, 219.6ms
# video 1/1 (frame 2/1003) c:\Users\user\Desktop\ML_PROJECT\Smart_AI_Surveillance_and_Behavior_Analysis_System\person_tracking_720p.avi: 384x640 14 persons, 1 car, 2 backpacks, 1 handbag, 1 cell phone, 193.3ms
# ...

# %%
# result = model('yolo_video.avi', save = True ,conf = .25)
